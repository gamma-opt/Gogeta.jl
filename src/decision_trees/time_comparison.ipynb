# %% [markdown]
# # TIME COMPARISON FOR SOLUTION METHODS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The number of levels (dimension of x-vector) and the number of leaves (dimension of y-vector) are massive.
#
# In the paper, the authors use a maximum tree depth around 25.
#
# This inflates the solution times and makes the split generation algorithm seem useful. In the concrete demo, tree depths of 3-5 were seen to perform the best.
